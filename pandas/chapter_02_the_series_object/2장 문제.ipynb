# %% [markdown]
# ## 1번째

# %%
superheroes=[
    "Batman",
    "Superman",
    "Spider-Man",
    "Iron Man",
    "Captain America",
    "Wonder Woman"
]

# %%
strength_levels=(100,120,90,95,110,120)

# %%
import pandas as pd
import numpy as np

# %%
pd.Series(data=superheroes)
# Out:
# 0             Batman
# 1           Superman
# 2         Spider-Man
# 3           Iron Man
# 4    Captain America
# 5       Wonder Woman
# dtype: object

# %%
pd.Series(data=strength_levels)
# Out:
# 0    100
# 1    120
# 2     90
# 3     95
# 4    110
# 5    120
# dtype: int64

# %%
heroes=pd.Series(data=strength_levels,index=superheroes)
heroes
# Out:
# Batman             100
# Superman           120
# Spider-Man          90
# Iron Man            95
# Captain America    110
# Wonder Woman       120
# dtype: int64

# %%
heroes.head(n=2)
# Out:
# Batman      100
# Superman    120
# dtype: int64

# %%
heroes.tail(n=4)
# Out:
# Spider-Man          90
# Iron Man            95
# Captain America    110
# Wonder Woman       120
# dtype: int64

# %%
len(heroes.unique())
#heroes.nunique()
# Out:
# 5

# %%
heroes.mean()
# Out:
# np.float64(105.83333333333333)

# %%
print(f"최대 능력치: {heroes.max()}, 그에 대응하는 index: {heroes.idxmax()}")
print(f"최소 능력치: {heroes.min()}, 그에 대응하는 index: {heroes.idxmin()}")
# Out:
# 최대 능력치: 120, 그에 대응하는 index: Superman
# 최소 능력치: 90, 그에 대응하는 index: Spider-Man

# %%
heroes.multiply(2)
# Out:
# Batman             200
# Superman           240
# Spider-Man         180
# Iron Man           190
# Captain America    220
# Wonder Woman       240
# dtype: int64

# %%
dict(heroes)
# Out:
# {'Batman': np.int64(100),
#  'Superman': np.int64(120),
#  'Spider-Man': np.int64(90),
#  'Iron Man': np.int64(95),
#  'Captain America': np.int64(110),
#  'Wonder Woman': np.int64(120)}
