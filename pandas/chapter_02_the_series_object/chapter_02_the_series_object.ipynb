# %% [markdown]
# ## 2.1 Overview of a Series

# %% [markdown]
# Series는 동일한 타입의 data만 담을 수 있으며, label이 있는 1차원 배열이다.
#
# Series는 list와 같이 일렬로 놓인 순서에 따라 값을 저장하며, 각 값에 key/label을 할당한다.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 2.1.1 Classes, and Instances

# %%
#Series class에서 object을 instance화한다.
#즉 Series object를 생성한다.
pd.Series()
# Out:
# Series([], dtype: object)

# %% [markdown]
# ### 2.1.2 Populating the Series with Values

# %%
#list에 있는 data로 Series object를 생성
ice_cream_flavors = [
    "Chocolate",
    "Vanilla",
    "Strawberry",
    "Rum Raisin",
]

pd.Series(ice_cream_flavors)
# Out:
# 0     Chocolate
# 1       Vanilla
# 2    Strawberry
# 3    Rum Raisin
# dtype: object

# %%
# The two lines below are equivalent
pd.Series(ice_cream_flavors)
pd.Series(data = ice_cream_flavors)
# Out:
# 0     Chocolate
# 1       Vanilla
# 2    Strawberry
# 3    Rum Raisin
# dtype: object

# %% [markdown]
# ### 2.1.3 Customizing the Series Index

# %% [markdown]
#         0     Chocolate
#         1       Vanilla
#         2    Strawberry
#         3    Rum Raisin
#
# 위에서 보는 것과 같이 Series의 각 값이 있는 줄마다 고유의 정수를 매핑하여 위치를 할당한다.
#
# 이 각 정수를 index라고 하며, index는 0부터 시작한다.
#
# 이러한 index를 통해서 Series내의 값에 접근할 수 있다(index가 그 값의 위치를 가리키기 때문이다.).
#
# 이러한 index위치 외에도 각 Series값에 index label을 할당하여 값과 고유한 index label을 매핑시킬 수 있다.

# %%
#문자열 list
ice_cream_flavors = [
    "Chocolate",
    "Vanilla",
    "Strawberry",
    "Rum Raisin",
]

#문자열 tuple
days_of_week = ("Monday", "Wednesday", "Friday", "Saturday")

# The two lines below are equivalent
pd.Series(ice_cream_flavors, days_of_week)
#매개변수 data는 Series에 값을 채우는 object을 상징한다.
#매개변수 index는 Series의 index label을 설정한다. 이를 통해 label과 위치 식별자(index값)이 하나로 동일해진다.
pd.Series(data = ice_cream_flavors, index = days_of_week)
# Out:
# Monday        Chocolate
# Wednesday       Vanilla
# Friday       Strawberry
# Saturday     Rum Raisin
# dtype: object

# %%
ex=pd.Series(data=ice_cream_flavors, index=days_of_week)
#index값으로 접근
print(ex[1])
#label로 동일한 값 접근
print(ex["Wednesday"])
# Out:
# Vanilla
# Vanilla
# /var/folders/g2/m_rjbg_d4fq330k9g6z2v24m0000gn/T/ipykernel_1010/4104452529.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(ex[1])

# %%
ice_cream_flavors = [
    "Chocolate",
    "Vanilla",
    "Strawberry",
    "Rum Raisin",
]

#index label중 Wednesday가 두 번 나오지만 오류는 없다.
#Series의 index label은 중복을 허용하기 때문이다.
#하지만 고유 index label를 사용해야 더 빨리 찾을 수 있다.
days_of_week = ("Monday", "Wednesday", "Friday", "Wednesday")

# The two lines below are equivalent
pd.Series(ice_cream_flavors, days_of_week)
pd.Series(data = ice_cream_flavors, index = days_of_week)
# Out:
# Monday        Chocolate
# Wednesday       Vanilla
# Friday       Strawberry
# Wednesday    Rum Raisin
# dtype: object

# %%
ex=pd.Series(index = days_of_week, data = ice_cream_flavors)
#index label이 중복된 행이 모두 출력된다.
ex["Wednesday"]
# Out:
# Wednesday       Vanilla
# Wednesday    Rum Raisin
# dtype: object

# %%
bunch_of_bools = [True, False, False]
pd.Series(bunch_of_bools)
# Out:
# 0     True
# 1    False
# 2    False
# dtype: bool

# %%
stock_prices = [985.32, 950.44]
time_of_day = ["Open", "Close"]
pd.Series(data = stock_prices, index = time_of_day)
# Out:
# Open     985.32
# Close    950.44
# dtype: float64

# %%
lucky_numbers = [4, 8, 15, 16, 23, 42]
pd.Series(lucky_numbers)
# Out:
# 0     4
# 1     8
# 2    15
# 3    16
# 4    23
# 5    42
# dtype: int64

# %%
lucky_numbers = [4, 8, 15, 16, 23, 42]
#Series의 값을 채우는 object는 정수형 list인데, dtype="float"를 통해 data type을 float로 형변환하였다.
pd.Series(lucky_numbers, dtype = "float")
# Out:
# 0     4.0
# 1     8.0
# 2    15.0
# 3    16.0
# 4    23.0
# 5    42.0
# dtype: float64

# %%
ex=pd.Series(lucky_numbers,dtype="bool")
ex
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# dtype: bool

# %%
ex=pd.Series(lucky_numbers, dtype="str")

print(ex)
print(type(ex[1]),"\n\n")

ex[1]
# Out:
# 0     4
# 1     8
# 2    15
# 3    16
# 4    23
# 5    42
# dtype: object
# <class 'str'>
# '8'

# %% [markdown]
# ### 2.1.4 Creating a Series with Missing Values

# %% [markdown]
# pandas는 파일을 가져오다가 결측값(손실된 값)을 발견하면, numpy의 nan이라는 object로 대체한다.
#
# 이 nan은 숫자가 아닌 정의되지 않은 값을 나타내는 placeholder object이다(null이랑 비슷).
#
# pandas는 nan값을 발견하면 숫자 값을 부동 소수점으로 자동 변환한다. 이를 통해 숫자 값과 결측값을 함께 저장할 수 있다.

# %%
#결측값 삽입
temperatures = [94, 88, np.nan, 91]

pd.Series(data = temperatures)
# Out:
# 0    94.0
# 1    88.0
# 2     NaN
# 3    91.0
# dtype: float64

# %% [markdown]
# ## 2.2 Create a Series from Python Objects

# %% [markdown]
# Series를 생성할 때 다양한 타입의 data로 Series object를 생성할 수 있다.

# %%
#dictionary로 Series object를 생성
calorie_info = {
    "Cereal": 125,
    "Chocolate Bar": 406,
    "Ice Cream Sundae": 342,
}

diet = pd.Series(calorie_info)
diet
# Out:
# Cereal              125
# Chocolate Bar       406
# Ice Cream Sundae    342
# dtype: int64

# %%
#dictionary의 key값이 Series의 index label이 되고, value값이 Series의 값이 된다.
diet["Cereal"]
# Out:
# np.int64(125)

# %%
#tuple로 Series object를 생성할 수 있다.
tu=pd.Series(data = ("Red", "Green", "Blue"))
tu
# Out:
# 0      Red
# 1    Green
# 2     Blue
# dtype: object

# %%
#tuple의 요소는 추가, 제거, 교체할 수 없지만 tuple로 만든 Series는 당연히 요소를 추가, 제거, 교체할 수 있다.
tu[0]="yello"
tu[0]
# Out:
# 'yello'

# %%
#tuple로 구성된 list로 Series object를 생성할 수 있다.
rgb_colors = [(120, 41, 26), (196, 165, 45)]
tu_list=pd.Series(data = rgb_colors)
tu_list
# Out:
# 0     (120, 41, 26)
# 1    (196, 165, 45)
# dtype: object

# %%
print(tu_list[0][0])
#이와 같이 tuple내 요소는 바꿀 수는 없다.
tu_list[0][0]=1
# Out:
# 120
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 print(tu_list[0][0])
#       2 #이와 같이 tuple내 요소는 바꿀 수는 없다.
# ----> 3 tu_list[0][0]=1
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# **NOTE**: I've commented out the code below so that the Notebook can run without raising an error.

# %% [markdown]
# Set 자료구조는 순서가 없는 고유한 값의 컬렉션이다.
#
# Set에는 순서 개념이나 dictionary와 같은 연괄 개념이 없기에 Set으로는 Series object를 생성할 수 없다.
#
# 왜냐, Set의 값을 저장하는 순서를 가정할 수 없기 때문이다.

# %%
my_set = {"Ricky", "Bobby"}
pd.Series(my_set)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 my_set = {"Ricky", "Bobby"}
# ----> 2 pd.Series(my_set)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/series.py:587, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     585         data = data.copy()
#     586 else:
# --> 587     data = sanitize_array(data, index, dtype, copy)
#     589     manager = _get_option("mode.data_manager", silent=True)
#     590     if manager == "block":
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/construction.py:639, in sanitize_array(data, index, dtype, copy, allow_2d)
#     630     return sanitize_array(
#     631         data,
#     632         index=index,
#    (...)    635         allow_2d=allow_2d,
#     636     )
#     638 else:
# --> 639     _sanitize_non_ordered(data)
# ...

# %% [markdown]
# 하지만 다음과 같이 Set으로 구성된 list로는 Series를 생성할 수 있다.
#
# list내 Set요소들이 각각 순서를 이루기 때문이다.

# %%
da=[{"first","second"},{"third","fourth"}]
pd.Series(data=da)
# Out:
# 0    {first, second}
# 1    {fourth, third}
# dtype: object

# %%
#Set을 정렬된 자료구조인 list로 형 변환하여 Series를 생성한다.
pd.Series(list(my_set))
# Out:
# 0    Ricky
# 1    Bobby
# dtype: object

# %%
#randint()함수로 ndarray object을 생성
random_data = np.random.randint(1, 101, 10)
random_data
# Out:
# array([77, 85,  2, 80, 21, 30, 74, 54, 93, 21])

# %%
#ndarray object로 Series object를 생성한다.
pd.Series(random_data)
# Out:
# 0    77
# 1    85
# 2     2
# 3    80
# 4    21
# 5    30
# 6    74
# 7    54
# 8    93
# 9    21
# dtype: int64

# %% [markdown]
# ## 2.3 Series Attributes

# %% [markdown]
# Attribute는 ojbect에 속하는 data의 조각이다. 즉 Attribute는 ojbect의 내부 상태에 대한 정보를 나타낸다.
#
# Series object는 여러 개의 작은 object들로 구성된다.
#
# Series는 numpy의 ndarray object를 사용하여 값을 저장하고, Index object를 사용하여 index label을 저장한다.
#
# pandas는 numpy에 종속적이다. 여러 면에서 Series는 핵심 numpy library object를 둘러싼 일종의 wrapper라 할 수 있다.

# %%
diet
# Out:
# Cereal              125
# Chocolate Bar       406
# Ice Cream Sundae    342
# dtype: int64

# %%
print("diet의 type:",type(diet))
#values라는 attribute로 값을 저장하는 ndarray object에 접근할 수 있다.
print("\ndiet라는 Series의 값:\n",diet.values)
#index라는 attribute로 index label을 저장하는 Index object에 접근할 수 있다.
print("\ndiet라는 Series의 index:\n",diet.index)
# Out:
# diet의 type: <class 'pandas.core.series.Series'>
#
# diet라는 Series의 값:
#  [125 406 342]
#
# diet라는 Series의 index:
#  Index(['Cereal', 'Chocolate Bar', 'Ice Cream Sundae'], dtype='object')

# %%
type(diet.values)
# Out:
# numpy.ndarray

# %%
diet.index
# Out:
# Index(['Cereal', 'Chocolate Bar', 'Ice Cream Sundae'], dtype='object')

# %%
type(diet.index)
# Out:
# pandas.core.indexes.base.Index

# %%
#Series의 data type반환
diet.dtype
# Out:
# dtype('int64')

# %%
#Series의 값의 개수(행의 개수)를 반환한다.
diet.size
# Out:
# 3

# %%
#차원을 tuple형태로 반환
diet.shape
# Out:
# (3,)

# %%
#모든 Series값이 고유한 경우 True반환
diet.is_unique
# Out:
# True

# %%
pd.Series(data = [3, 3]).is_unique
# Out:
# False

# %%
#각 Series값이 자신의 이전 값보다 크면 True반환
pd.Series(data = [1, 3, 6]).is_monotonic_increasing
# Out:
# True

# %%
pd.Series(data = [1, 6, 3]).is_monotonic_increasing
# Out:
# False

# %% [markdown]
# ## 2.4 Retrieving the First and Last Rows

# %%
values = range(0, 500, 5)
nums = pd.Series(data = values)
nums
# Out:
# 0       0
# 1       5
# 2      10
# 3      15
# 4      20
#      ...
# 95    475
# 96    480
# 97    485
# 98    490
# 99    495
# Length: 100, dtype: int64

# %%
nums.head(3)
# Out:
# 0     0
# 1     5
# 2    10
# dtype: int64

# %%
nums.head(n = 3)
# Out:
# 0     0
# 1     5
# 2    10
# dtype: int64

# %%
nums.head()
# Out:
# 0     0
# 1     5
# 2    10
# 3    15
# 4    20
# dtype: int64

# %%
nums.tail(6)
# Out:
# 94    470
# 95    475
# 96    480
# 97    485
# 98    490
# 99    495
# dtype: int64

# %%
nums.tail()
# Out:
# 95    475
# 96    480
# 97    485
# 98    490
# 99    495
# dtype: int64

# %% [markdown]
# ## 2.5 Mathematical Operations

# %% [markdown]
# pandas의 대부분 수학적 method는 기본적으로 결측값을 무시한다.

# %% [markdown]
# ### 2.5.1 Statistical Operations

# %%
numbers = pd.Series([1, 2, 3,None , 4, 5])  #None과 np.nan은 같다.
numbers
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
#count()는 null이 아닌 값의 개수를 계산한다.
numbers.count()
# Out:
# np.int64(5)

# %%
#sum()은 Series의 값을 모두 더한다(결측값은 무시).
numbers.sum()
# Out:
# np.float64(15.0)

# %%
#skipna에 False을 전달하여 결측값을 강제로 포함할 수 있다.
#하지만 nan값을 누적 합계에 더할 수 없기에 최종적으로는 nan을 반환한다.
numbers.sum(skipna = False)
# Out:
# np.float64(nan)

# %%
#min_count는 pandas가 합을 계산하기 위해 Series가 보유해야 하는 유효한 값의 최소 개수를 설정한다.
#전체 Series값 중 유효값이 3보다 적으면 nan을 출력하고, 3보다 크면 nan을 제외한 누적합을 출력한다.
numbers.sum(min_count = 3)
# Out:
# np.float64(15.0)

# %%
numbers.sum(min_count = 6)
# Out:
# np.float64(nan)

# %%
#Series의 값을 모두 곱한다.
numbers.product()
# Out:
# np.float64(120.0)

# %%
numbers.product(skipna = False)
# Out:
# np.float64(nan)

# %%
numbers.product(min_count = 3)
# Out:
# np.float64(120.0)

# %%
numbers
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
#누적 합계를 값으로 갖는 새 Series를 반환한다.
numbers.cumsum()
# Out:
# 0     1.0
# 1     3.0
# 2     6.0
# 3     NaN
# 4    10.0
# 5    15.0
# dtype: float64

# %%
#skipna에 False을 전달하면 Series는 첫 번째 누락 값이 있는 index까지 누적 합을 구하고, 
#나머지 값에 대해서는 NaN을 반환한다.
numbers.cumsum(skipna = False)
# Out:
# 0    1.0
# 1    3.0
# 2    6.0
# 3    NaN
# 4    NaN
# 5    NaN
# dtype: float64

# %%
numbers
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
#pct_change()는 한 Series값에서 다음 값까지의 변동 비율을 반환한다.
#즉 각 index에서 현재 index 값에서 이전 index값을 뺀 다음에 결과를 이전 index값으로 나눈다.
#index 0에서는 이전 값과 비교할 수 없으니 NaN값이 반환된다.
#현재 index혹은 이전 index가 nan값일 경우 그 index바로 이전 index값을 대체한다.
#3이 NaN값이므로, 3에 대한 값을 2에 대한 값으로 대체하여 사용한다.
numbers.pct_change()
# Out:
# /var/folders/g2/m_rjbg_d4fq330k9g6z2v24m0000gn/T/ipykernel_1010/2109072074.py:6: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   numbers.pct_change()
# 0         NaN
# 1    1.000000
# 2    0.500000
# 3    0.000000
# 4    0.333333
# 5    0.250000
# dtype: float64

# %%
#fill_method는 pct_change가 NaN값을 대체하는 방법을 정의한다.
# The three lines below are equivalent
numbers.pct_change()
numbers.pct_change(fill_method = "pad")
numbers.pct_change(fill_method = "ffill")
# Out:
# /var/folders/g2/m_rjbg_d4fq330k9g6z2v24m0000gn/T/ipykernel_1010/269384618.py:3: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   numbers.pct_change()
# /var/folders/g2/m_rjbg_d4fq330k9g6z2v24m0000gn/T/ipykernel_1010/269384618.py:4: FutureWarning: The 'fill_method' keyword being not None and the 'limit' keyword in Series.pct_change are deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   numbers.pct_change(fill_method = "pad")
# ...

# %%
#nan값을 다음 유요한 관측값으로 대체할 수도 있다.
# The two lines below are equivalent
numbers.pct_change(fill_method = "bfill")
numbers.pct_change(fill_method = "backfill")
# Out:
# /var/folders/g2/m_rjbg_d4fq330k9g6z2v24m0000gn/T/ipykernel_1010/836015330.py:3: FutureWarning: The 'fill_method' keyword being not None and the 'limit' keyword in Series.pct_change are deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   numbers.pct_change(fill_method = "bfill")
# /var/folders/g2/m_rjbg_d4fq330k9g6z2v24m0000gn/T/ipykernel_1010/836015330.py:4: FutureWarning: The 'fill_method' keyword being not None and the 'limit' keyword in Series.pct_change are deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   numbers.pct_change(fill_method = "backfill")
# 0         NaN
# 1    1.000000
# 2    0.500000
# 3    0.333333
# 4    0.000000
# 5    0.250000
# dtype: float64

# %%
#Series값의 평균을 반환
numbers.mean()
# Out:
# np.float64(3.0)

# %%
#Series값의 중앙값 반환
numbers.median()
# Out:
# 3.0

# %%
#Series값의 표준편차를 반환
numbers.std()
# Out:
# 1.5811388300841898

# %%
numbers.max()
# Out:
# 5.0

# %%
numbers.min()
# Out:
# 1.0

# %%
animals = pd.Series(["koala", "aardvark", "zebra"])
animals
# Out:
# 0       koala
# 1    aardvark
# 2       zebra
# dtype: object

# %%
#알파벳 순으로 정렬했을 때 알바벳 끝 부분에 가장 가까운 문자열
animals.max()
# Out:
# 'zebra'

# %%
#알바벳 시작 부분에 가장 가까운 문자열
animals.min()
# Out:
# 'aardvark'

# %%
#Series값에 대한 여러가지 통계값이 반환된다.
numbers.describe()
# Out:
# count    5.000000
# mean     3.000000
# std      1.581139
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000
# dtype: float64

# %%
#Series에서 임의의 값을 선택한다.
numbers.sample(3)
# Out:
# 4    4.0
# 0    1.0
# 3    NaN
# dtype: float64

# %%
authors = pd.Series(
    ["Hemingway", "Orwell", "Dostoevsky", "Fitzgerald", "Orwell"]
)

#Series에서 고유한 값의 ndarray를 반환한다.
#즉 값을 중복없이 한 번만 나타나는 배열로써 반환한다.
authors.unique()
# Out:
# array(['Hemingway', 'Orwell', 'Dostoevsky', 'Fitzgerald'], dtype=object)

# %%
#Series내 고유한 값의 개수를 반환한다.
authors.nunique()
# Out:
# 4

# %% [markdown]
# ### 2.5.2 Arithmetic Operations

# %% [markdown]
# pandas는 Series값을 내부적으로 numpy의 ndarray에 저장하기 때문에 다음과 같은 수학적 계산도 numpy에게 넘어간다.

# %%
s1 = pd.Series(data = [5, np.nan, 15], index = ["A", "B", "C"])
s1
# Out:
# A     5.0
# B     NaN
# C    15.0
# dtype: float64

# %%
s1 + 3
# Out:
# A     8.0
# B     NaN
# C    18.0
# dtype: float64

# %%
s1.add(3)
# Out:
# A     8.0
# B     NaN
# C    18.0
# dtype: float64

# %%
# The three lines below are equivalent
s1 - 5
s1.sub(5)
s1.subtract(5)
# Out:
# A     0.0
# B     NaN
# C    10.0
# dtype: float64

# %%
# The three lines below are equivalent
s1 * 2
s1.mul(2)
s1.multiply(2)
# Out:
# A    10.0
# B     NaN
# C    30.0
# dtype: float64

# %%
# The three lines below are equivalent
s1 / 2
s1.div(2)
s1.divide(2)
# Out:
# A    2.5
# B    NaN
# C    7.5
# dtype: float64

# %%
# The two lines below are equivalent
s1 // 4
s1.floordiv(4)
# Out:
# A    1.0
# B    NaN
# C    3.0
# dtype: float64

# %%
# The two lines below are equivalent
s1 % 3
s1.mod(3)
# Out:
# A    2.0
# B    NaN
# C    0.0
# dtype: float64

# %% [markdown]
# ### 2.5.3 Broadcasting

# %%
s1 = pd.Series([1, 2, 3], index = ["A", "B", "C"])
s2 = pd.Series([4, 5, 6], index = ["A", "B", "C"])

# %%
s1 + s2
# Out:
# A    5
# B    7
# C    9
# dtype: int64

# %%
s1 = pd.Series([1, 2, 3], index = ["A", "B", "C"])
s2 = pd.Series([4, 5, 6], index = ["a", "b", "c"])
#두 Series의 index label이 서로 다르기 때문에 합이 제대로 연산되지 못한다.
s1 + s2
# Out:
# A   NaN
# B   NaN
# C   NaN
# a   NaN
# b   NaN
# c   NaN
# dtype: float64

# %%
s1 = pd.Series(data = [3, 6, np.nan, 12])
s2 = pd.Series(data = [2, 6, np.nan, 12])

# %%
# The two lines below are equivalent
#pandas는 nan값을 다른 nan과 다르다고 간주하기에 2의 값이 False로 반환된다.
s1 == s2
s1.eq(s2)
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
# The two lines below are equivalent
s1 != s2
s1.ne(s2)
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
s1 = pd.Series(
    data = [5, 10, 15], index = ["A", "B", "C"]
)

s2 = pd.Series(
    data = [4, 8, 12, 14], index = ["B", "C", "D", "E"]
)

# %%
s1 + s2
# Out:
# A     NaN
# B    14.0
# C    23.0
# D     NaN
# E     NaN
# dtype: float64

# %% [markdown]
# ## 2.6 Passing the Series to Python's Built-In Functions

# %%
cities = pd.Series(
    data = ["San Francisco", "Los Angeles", "Las  Vegas", np.nan]
)

# %%
len(cities)
# Out:
# 4

# %%
type(cities)
# Out:
# pandas.core.series.Series

# %%
#object의 attribute와 method을 문자열로 list에 담아 반환한다.
dir(cities)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__column_consortium_standard__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__firstlineno__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
#Series를 list로 변환
list(cities)
# Out:
# ['San Francisco', 'Los Angeles', 'Las  Vegas', nan]

# %%
#Series를 dictionary로 변환
dict(cities)
# Out:
# {0: 'San Francisco', 1: 'Los Angeles', 2: 'Las  Vegas', 3: nan}

# %%
cities
# Out:
# 0    San Francisco
# 1      Los Angeles
# 2       Las  Vegas
# 3              NaN
# dtype: object

# %%
#Series에 "Las Vegas"라는 값이 있는지 확인
"Las Vegas" in cities
# Out:
# False

# %%
#Series에 2라는 index값이 있는지 확인
2 in cities
# Out:
# True

# %%
"Las Vegas" in cities.values
# Out:
# False

# %%
100 not in cities
# Out:
# True

# %%
"Paris" not in cities.values
# Out:
# True

# %% [markdown]
# ## 2.7 Coding Challenge

# %% [markdown]
# ### 2.7.1 Problems

# %% [markdown]
# ### 2.7.2 Solutions

# %%
superheroes = [
    "Batman",
    "Superman",
    "Spider-Man",
    "Iron Man",
    "Captain America",
    "Wonder Woman"
]

# %%
strength_levels = (100, 120, 90, 95, 110, 120)

# %%
pd.Series(superheroes)
# Out:
# 0             Batman
# 1           Superman
# 2         Spider-Man
# 3           Iron Man
# 4    Captain America
# 5       Wonder Woman
# dtype: object

# %%
pd.Series(data = strength_levels)
# Out:
# 0    100
# 1    120
# 2     90
# 3     95
# 4    110
# 5    120
# dtype: int64

# %%
heroes = pd.Series(
    data = strength_levels, index = superheroes
)

heroes
# Out:
# Batman             100
# Superman           120
# Spider-Man          90
# Iron Man            95
# Captain America    110
# Wonder Woman       120
# dtype: int64

# %%
heroes.head(2)
# Out:
# Batman      100
# Superman    120
# dtype: int64

# %%
heroes.tail(4)
# Out:
# Spider-Man          90
# Iron Man            95
# Captain America    110
# Wonder Woman       120
# dtype: int64

# %%
heroes.nunique()
# Out:
# 5

# %%
heroes.mean()
# Out:
# 105.83333333333333

# %%
heroes.max()
# Out:
# 120

# %%
heroes.min()
# Out:
# 90

# %%
heroes * 2
# Out:
# Batman             200
# Superman           240
# Spider-Man         180
# Iron Man           190
# Captain America    220
# Wonder Woman       240
# dtype: int64

# %%
dict(heroes)
# Out:
# {'Batman': 100,
#  'Superman': 120,
#  'Spider-Man': 90,
#  'Iron Man': 95,
#  'Captain America': 110,
#  'Wonder Woman': 120}

# %% [markdown]
# ## 2.7 Summary
