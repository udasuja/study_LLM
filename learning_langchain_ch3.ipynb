# %%
# !sudo apt-get install -y zstd
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   zstd
# 0 upgraded, 1 newly installed, 0 to remove and 42 not upgraded.
# Need to get 603 kB of archives.
# After this operation, 1,695 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 zstd amd64 1.4.8+dfsg-3build1 [603 kB]
# Fetched 603 kB in 0s (2,833 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package zstd.
# ...

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
import subprocess
import time

# 서버를 백그라운드에서 실행
subprocess.Popen(["ollama", "serve"])
time.sleep(3) # 서버가 완전히 켜질 때까지 잠시 대기

# %%
#사용할 llm 다운로드
# !ollama pull llama3.1

# %%
#ollama용 langchain 다운로드
# !pip install -qU langchain-ollama

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    model="llama3.1",
    temperature=0,
    # other params...
)

# %%
llm.invoke("하늘이")
# Out:
# AIMessage(content='하늘에 있는 별을 보는 것은 많은 사람들에게 즐거운 일입니다. 하늘의 별은 밤하늘에 빛나는 작은 별로, 우리가 볼 수 있는 가장 가까운 별 중 하나입니다.\n\n별은 태양계에서 가장 멀리 떨어진 천체 중 하나이며, 우리에게 매우 먼 거리에 있습니다. 하지만 별은 우리에게 많은 것을 제공합니다. 예를 들어, 별은 우리에게 빛을 주고, 밤하늘의 아름다움을 보여줍니다.\n\n별은 또한 우주에 대한我们的 이해를 높여주는 중요한 연구 대상입니다. 별은 우주에서 발생하는 다양한 현상을 연구하여, 우주의 비밀을 밝히는 데 도움이 됩니다.\n\n또한, 별은 우리에게 영감을 주고, 꿈을 키워줍니다. 많은 사람들은 별을 보면서 자신의 목표를 세우고, 자신이 원하는 것을 이루기 위해 노력합니다.\n\n따라서, 하늘에 있는 별은 우리에게 매우 중요한 의미를 가지고 있습니다. 그것은 우리에게 빛을 주고, 밤하늘의 아름다움을 보여주며, 우주의 비밀을 밝히는 데 도움이 됩니다.', additional_kwargs={}, response_metadata={'model': 'llama3.1', 'created_at': '2026-04-01T00:26:44.534712416Z', 'done': True, 'done_reason': 'stop', 'total_duration': 105714796900, 'load_duration': 98569106474, 'prompt_eval_count': 13, 'prompt_eval_duration': 74077954, 'eval_count': 255, 'eval_duration': 6350297579, 'logprobs': None, 'model_name': 'llama3.1', 'model_provider': 'ollama'}, id='lc_run--019d466d-debf-7fd3-bb33-265150ebdfb0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata
# ...

# %% [markdown]
# ollama embedding 사용법

# %%
#embedding model 다운
# !ollama pull qwen3-embedding

# %%
#list내 각 문서에 대해 embedding
from langchain_ollama import OllamaEmbeddings

model=OllamaEmbeddings(model='qwen3-embedding')
embeddings=model.embed_documents([
    'Hi there!',
    'oh, hello!',
    'what\'s your name?',
    'My friends call me World',
    'Hello World'
])

# %%
print(f"{'Hi there!'}에 대한 embedding은 다음과 같다.")
print(embeddings[0])
# Out:
# Hi there!에 대한 embedding은 다음과 같다.
# ...

# %% [markdown]
# ##colab상에서 PGVector 사용법

# %%
# 1. PostgreSQL 및 빌드 필수 패키지 설치
# !sudo apt-get -y -qq update
# !sudo apt-get -y -qq install postgresql postgresql-contrib postgresql-server-dev-all build-essential

# 2. pgvector 소스코드 클론 및 컴파일 설치
# !git clone https://github.com/pgvector/pgvector.git
# %cd pgvector
# !make
# !sudo make install
# %cd ..

# 3. PostgreSQL 서버 시작
# !sudo service postgresql start

# 4. 테스트용 유저, 데이터베이스 생성 및 권한 부여
# !sudo -u postgres psql -c "CREATE USER colabuser WITH PASSWORD 'colabpass';"
# !sudo -u postgres psql -c "CREATE DATABASE colabdb OWNER colabuser;"
# !sudo -u postgres psql -c "GRANT ALL PRIVILEGES ON DATABASE colabdb TO colabuser;"

# 5. 생성한 DB에 pgvector 확장 기능(Extension) 활성화
# !sudo -u postgres psql -d colabdb -c "CREATE EXTENSION vector;"
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 41.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# (Reading database ... 122375 files and directories currently installed.)
# Preparing to unpack .../libc6-dev_2.35-0ubuntu3.13_amd64.deb ...
# Unpacking libc6-dev:amd64 (2.35-0ubuntu3.13) over (2.35-0ubuntu3.9) ...
# Preparing to unpack .../libc-dev-bin_2.35-0ubuntu3.13_amd64.deb ...
# ...

# %%
#파이썬에서 연결할 패키지를 설치합니다.
# !pip install -qU langchain-postgres psycopg[binary] langchain-core
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 36.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.7/506.7 kB 34.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 83.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.8/212.8 kB 13.8 MB/s eta 0:00:00

# %%
# 2. Ollama 서버를 백그라운드에서 실행
# !nohup ollama serve > ollama.log 2>&1 &

# 3. 서버가 켜질 때까지 잠시 대기
# !sleep 3

# %%
from langchain_postgres.vectorstores import PGVector
from langchain_core.embeddings import FakeEmbeddings

# 1. 연결 정보 (1단계에서 설정한 colabuser / colabpass / colabdb 사용)
connection_string = "postgresql+psycopg://colabuser:colabpass@localhost:5432/colabdb"

# 2. 임베딩 모델 (테스트용 가짜 임베딩 3차원)
# 실제 사용 시에는 OpenAIEmbeddings 등 사용
embeddings = FakeEmbeddings(size=3)

# 3. PGVector 객체 초기화
db = PGVector(
    embeddings=embeddings,
    collection_name="test_collection",
    connection=connection_string,
    use_jsonb=True,
)

# 4. 데이터 삽입 테스트
docs = ["안녕하세요! Colab 내부 DB 테스트입니다.", "pgvector가 성공적으로 설치되었습니다."]
db.add_texts(docs)

# 5. 유사도 검색 테스트
results = db.similarity_search("테스트", k=1)

print("✅ 저장 성공 및 검색 결과:")
print(results[0].page_content)
# Out:
# ✅ 저장 성공 및 검색 결과:
# pgvector가 성공적으로 설치되었습니다.

# %%
#langchain package 설치
# !pip install -qU langchain
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.7/112.7 kB 5.7 MB/s eta 0:00:00

# %%
#langchain package 설치
# !pip install -qU langchain-classic
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 21.1 MB/s eta 0:00:00

# %%
# !pip install -qU langchain_community
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 38.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 2.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.33.1 which is incompatible.

# %% [markdown]
# indexing작업

# %%
from langchain_community.document_loaders import TextLoader
from langchain_ollama import OllamaEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_postgres.vectorstores import PGVector
from langchain_ollama import ChatOllama
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import chain

# %%
connection="postgresql+psycopg://colabuser:colabpass@localhost:5432/colabdb"

#문서를 로드 후 분할
raw_documents=TextLoader("./test.txt",encoding="utf-8").load()
text_splitter=RecursiveCharacterTextSplitter(
    chunk_size=1000,chunk_overlap=200
)
documents=text_splitter.split_documents(raw_documents)

#문서에 대한 임베딩 생성
embeddings_model=OllamaEmbeddings(model='qwen3-embedding')

db=PGVector.from_documents(
    documents,embeddings_model,connection=connection
)

# %% [markdown]
# langchain을 활용해 사용자 질의와 유사한 문서를 찾는 검색 단계를 구현

# %%
#vector storage에서 관련 문서 검색
retriever=db.as_retriever()

query='고대 그리스 철학사의 주요 인물은 누구인가요?'

#관련 문서 받아오기
print(retriever.invoke(query))
# Out:
# [Document(id='12b28450-2346-4d26-8da2-4ed42abe2341', metadata={'source': './test.txt'}, page_content='---\nChapter 5: Philosophy and Science in Ancient Greece\nAncient Greece was a fertile ground for philosophical thought and scientific inquiry, laying the foundational principles that have shaped Western intellectual traditions. Greek philosophers and scientists pursued knowledge across diverse fields, seeking to understand the nature of reality, ethics, politics, and the natural world. This chapter delves into the major philosophical schools, key scientific advancements, influential thinkers, and the enduring impact of Greek intellectual pursuits on subsequent generations.\nPhilosophical Schools and Movements\nPre-Socratic Philosophers\nBefore Socrates, Greek philosophers known as Pre-Socratics focused primarily on cosmology, metaphysics, and the nature of the universe.\nThales of Miletus: Proposed that water was the fundamental substance (arche) underlying all matter.\nAnaximander:
# ...

# %%
#vector storage에서 2개의 관련 문서 검색
retriever=db.as_retriever(search_kwargs={'k':2})
query='고대 그리스 철학사의 주요 인물은 누구인가요?'

#관련 문서 받아오기
docs=retriever.invoke(query)
print(docs)
# Out:
# [Document(id='12b28450-2346-4d26-8da2-4ed42abe2341', metadata={'source': './test.txt'}, page_content='---\nChapter 5: Philosophy and Science in Ancient Greece\nAncient Greece was a fertile ground for philosophical thought and scientific inquiry, laying the foundational principles that have shaped Western intellectual traditions. Greek philosophers and scientists pursued knowledge across diverse fields, seeking to understand the nature of reality, ethics, politics, and the natural world. This chapter delves into the major philosophical schools, key scientific advancements, influential thinkers, and the enduring impact of Greek intellectual pursuits on subsequent generations.\nPhilosophical Schools and Movements\nPre-Socratic Philosophers\nBefore Socrates, Greek philosophers known as Pre-Socratics focused primarily on cosmology, metaphysics, and the nature of the universe.\nThales of Miletus: Proposed that water was the fundamental substance (arche) underlying all matter.\nAnaximander:
# ...

# %% [markdown]
# 검색된 문서를 기반으로 prompt를 생성하고, 이 prompt를 기반으로 LLM이 사용자 질의에 대한 답변을 생성한다.

# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import ChatPromptTemplate

retriever=db.as_retriever()

#prompt 구조
prompt=ChatPromptTemplate.from_template(
    '''다음 컨텍스트만 사용해 질문에 답하세요.
    컨텍스트:{context}

    질문:{question}
    '''
)

llm=ChatOllama(model="llama3.1",temperature=0)
llm_chain=prompt|llm

#관련 문서를 사용한 답변
result=llm_chain.invoke({'context':docs,'question':query})

print(result)

#query:  '고대 그리스 철학사의 주요 인물은 누구인가요?'
#answer: '고대 그리스 철학사에서 주요 인물로는 소크라테스와 플라톤이 있습니다.'
# Out:
# content='고대 그리스 철학사에서 주요 인물로는 소크라테스와 플라톤이 있습니다.' additional_kwargs={} response_metadata={'model': 'llama3.1', 'created_at': '2026-04-01T00:34:13.411886253Z', 'done': True, 'done_reason': 'stop', 'total_duration': 25760343559, 'load_duration': 24320038046, 'prompt_eval_count': 512, 'prompt_eval_duration': 588755747, 'eval_count': 25, 'eval_duration': 795101388, 'logprobs': None, 'model_name': 'llama3.1', 'model_provider': 'ollama'} id='lc_run--019d4675-f081-7702-bf8e-821b776c587d-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 512, 'output_tokens': 25, 'total_tokens': 537}

# %% [markdown]
# 위 과정을 단일 함수로 캡슐화한다.

# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import chain

retriever = db.as_retriever()

prompt=ChatPromptTemplate.from_template(
    '''다음 컨텍스트만 사용해 질문에 답하세요.
    컨텍스트:{context}

    질문:{question}
    '''
)

llm=ChatOllama(model="llama3.1",temperature=0)

@chain
def qa(input):
  #관련 문서 검색
  docs=retriever.invoke(input)
  #prompt formatting
  formatted=prompt.invoke({'context':docs,'question':input})
  #답변생성
  answer=llm.invoke(formatted)
  return answer

#실행
result=qa.invoke(query)
print(result.content)

#query:   '고대 그리스 철학사에서 주요 인물로는 소크라테스와 플라톤이 있습니다.'
#answer:  '고대 그리스 철학사에서 주요 인물로는 소크라테스와 플라톤이 있습니다. 소크라테스는 철학의 아버지로 불리며,
#          그의 사상과 방법론은 고대 그리스 철학의 발전에 큰 영향을 미쳤습니다.
#          플라톤은 소크라테스의 제자로, 그의 철학적 사상을 담은 대화록인 플라톤의 대화가 있습니다.'
# Out:
# 고대 그리스 철학사에서 주요 인물로는 소크라테스와 플라톤이 있습니다. 소크라테스는 철학의 아버지로 불리며, 그의 사상과 방법론은 고대 그리스 철학의 발전에 큰 영향을 미쳤습니다. 플라톤은 소크라테스의 제자로, 그의 사상을 정립하고 확장하여 고대 그리스 철학의 주요 흐름을 형성했습니다.
#
# 또한, 이 문서에는 다른 여러 인물과 학파도 언급되어 있습니다. 예를 들어, 프리소크라테스 학파는 소크라테스 이전에 활동했던 철학자들의 집단으로, 탈레스와 아나크세만데르가 대표적인 인물입니다. 소피스트들은 고대 그리스의 철학적 사상과 교육을 전달하는 데 중요한 역할을 한 학파로, 프로타고라스와 기톤이 주요 인물입니다.
#
# 이러한 인물들과 학파는 고대 그리스 철학사에서 중요한 역할을 하였으며, 현대 철학에까지 영향을 미쳤습니다.

# %%
#검색된 문서를 반환
@chain
def qa(input):
  #관련 문서 검색
  docs=retriever.invoke(input)
  #prompt formatting
  formatted=prompt.invoke({'context':docs,'question':input})
  #답변 생성
  answer=llm.invoke(formatted)
  return {'answer':answer,'docs':docs}

# %%
#표현이 미흡한 사용자의 query를 실행
#관련 질문을 하기 전에 관련 없는 정보로 시작하는 쿼리
query="""일어나서 이를 닦고 뉴스를 읽었어요.
그러다 전자레인지에 음식을 넣어둔 걸 깜빡했네요.
고대 그리스 철학사의 주요인물은 누구인가요?"""

#위 query에 대한 답변
qa.invoke(query)
# Out:
# {'answer': AIMessage(content='고대 그리스 철학사에서 주요 인물로는 소크라테스, 플라톤, 아리스토텔레스 등이 있습니다.', additional_kwargs={}, response_metadata={'model': 'llama3.1', 'created_at': '2026-04-01T00:34:26.5520214Z', 'done': True, 'done_reason': 'stop', 'total_duration': 2534879524, 'load_duration': 192998076, 'prompt_eval_count': 1043, 'prompt_eval_duration': 1023022249, 'eval_count': 34, 'eval_duration': 1240296170, 'logprobs': None, 'model_name': 'llama3.1', 'model_provider': 'ollama'}, id='lc_run--019d4676-7e90-7512-ae21-90910fa40eeb-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1043, 'output_tokens': 34, 'total_tokens': 1077}),
# ...

# %%
#query rewrite prompt를 사용하여 정확도를 높인다.
rewrite_prompt=ChatPromptTemplate.from_template(
    '''
    웹 검색 엔진이 주어진 질문에 답할 수 있도록 더 나은 영문 검색어를 제공하세요. 쿼리는 \'**\'로 끝내세요.

    질문: {x}

    답변:
    '''
)

def parse_rewriter_output(message):
  return message.content.strip('\'').strip('**')

#rewrite_prompt을 기반으로 llm이 쿼리를 재작성한다. 이때 llm이 재작성한 쿼리의 output은 위 함수의 입력이 된다.
rewriter=rewrite_prompt|llm|parse_rewriter_output

@chain
def qa_rrr(input):
  #query rewrite
  new_query=rewriter.invoke(input)
  print('재작성한 쿼리: ',new_query)
  #재작성된 쿼리로 관련 문서 검색
  docs=retriever.invoke(new_query)
  #prompt formatting
  formatted=prompt.invoke({'context':docs,'question':new_query})
  #답변 생성
  answer=llm.invoke(formatted)
  return answer

print('\n재작성한 쿼리로 모델 호출\n')

#재작성한 쿼리로 재실행
result=qa_rrr.invoke(query)
print(result.content)
# Out:
# 재작성한 쿼리로 모델 호출
#
# 재작성한 쿼리:  웹 검색 엔진에서 "고대 그리스 철학사 주요 인물"**을 검색하세요.
# 고대 그리스 철학의 주요 인물로는 다음과 같은 사람들을 들 수 있습니다.
#
# 1. 소크라테스(Socrates): 소크라테스는 고대 그리스 철학의 아버지로 여겨지며, 그의 학생들인 플라톤과 아리스토텔레스가 그의 사상을 계승하여 발전시켰습니다.
# 2. 플라톤(Plato): 플라톤은 소크라테스의 제자로, 고대 그리스 철학의 대표적인 학파인 플aton주의를 창안했습니다. 그는 "정의", "아름다움", "진리"와 같은 개념을 탐구하였으며, 그의 저서인 대화는 고대 그리스 철학사에서 가장 중요한 작품 중 하나입니다.
# 3. 아리스토텔레스(Aristotle): 아리스토텔레스는 플라톤의 제자로, 고대 그리스 철학의 대표적인 학파인 스토아주의를 창안했습니다. 그는 자연philosophy와 ethicsto explore하고, 그의 저서인 "메타피직스"는 고대 그리스 철학사에서 가장 중요한 작품 중 하나입니다.
# 4. 헤라클레이토스(Heraclitus): 헤라클레이토스는 고대 그리스 철학의 대표적인 학파인 헤라클레이티즘을 창안했습니다. 그는 "변화"와 "흐름"에 대한 사상을 탐구하였으며, 그의 저서인 "헤라클레이투스 fragments"는 고대 그리스 철학사에서 중요한 작품 중 하나입니다.
# 5. 데모크리토스(Democritus): 데모크리토스는 고대 그리스 철학의 대표적인 학파인 에피쿠로주의를 창안했습니다. 그는 "원자론"에 대한 사상을 탐구하였으며, 그의 저서인 "데모크리토스 fragments"는 고대 그리스 철학사에서 중요한 작품 중 하나입니다.
#
# 이 외에도 고대 그리스 철학의 주요 인물로는 소피스트들(소피스트: 고대 그리스 철학자들의 사상을 탐구하고, 교육을 제공하는 사람들), 에피쿠로스(Epicurus), 스토아 학파의 대표자들 등이 있습니다.

# %% [markdown]
# 다중 쿼리 검색

# %%
from langchain_core.prompts import ChatPromptTemplate

#prompt for multi-query
perspectives_prompt=ChatPromptTemplate.from_template(
    '''당신은 AI 언어 모델 어시스턴트입니다. 주어진 사용자 질문의 다섯 가지 버전을 생성하여 벡터 데이터베이스에서 관련 문서를 검색하세요.
    사용자 질문에 대한 다양한 관점을 생성함으로써 사용자가 거리 기반 유사도 검색의 한계를 극복할 수 있도록 돕는 것이 목표입니다.
    이러한 대체 질문을 개행으로 구분하여 제공하세요.
    원래 질문: {question}'''
)

llm=ChatOllama(model='llama3.1')

def parse_queries_output(message):
  return message.content.split('\n')

query_gen=perspectives_prompt | llm |parse_queries_output

# %%
query_gen
# Out:
# ChatPromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, template='당신은 AI 언어 모델 어시스턴트입니다. 주어진 사용자 질문의 다섯 가지 버전을 생성하여 벡터 데이터베이스에서 관련 문서를 검색하세요.\n    사용자 질문에 대한 다양한 관점을 생성함으로써 사용자가 거리 기반 유사도 검색의 한계를 극복할 수 있도록 돕는 것이 목표입니다.\n    이러한 대체 질문을 개행으로 구분하여 제공하세요.\n    원래 질문: {question}'), additional_kwargs={})])
# | ChatOllama(model='llama3.1')
# | RunnableLambda(parse_queries_output)

# %%
#관련 문서 집합
def get_unique_union(document_lists):
  #목록 여러 개를 포함한 list를 평탄화하고 중복 제거
  deduped_docs={
      doc.page_content: doc for sublist in document_lists for doc in sublist
  }
  #고유한 문서만 반환
  return list(deduped_docs.values())

retrieval_chain=query_gen|retriever.batch|get_unique_union

# %%
retrieval_chain
# Out:
# ChatPromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, template='당신은 AI 언어 모델 어시스턴트입니다. 주어진 사용자 질문의 다섯 가지 버전을 생성하여 벡터 데이터베이스에서 관련 문서를 검색하세요.\n    사용자 질문에 대한 다양한 관점을 생성함으로써 사용자가 거리 기반 유사도 검색의 한계를 극복할 수 있도록 돕는 것이 목표입니다.\n    이러한 대체 질문을 개행으로 구분하여 제공하세요.\n    원래 질문: {question}'), additional_kwargs={})])
# | ChatOllama(model='llama3.1')
# | RunnableLambda(parse_queries_output)
# | RunnableLambda(batch)
# | RunnableLambda(get_unique_union)

# %%
#사용자 질문과 검색된 각각의 관련 문서를 결합한 prompt 구성
prompt=ChatPromptTemplate.from_template(
    '''
    다음 컨텍스트만 사용해 질문에 답하세요.

    컨텍스트:{context}

    질문:{question}
    '''
)

query='고대 그리스 철학사의 주요 인물은 누구인가요?'

@chain
def multi_query_qa(input):
  #관련 문서 검색
  docs=retrieval_chain.invoke(input)
  print(f"query:{input}\ndocs:{docs} ")
  formatted=prompt.invoke({
      'context':docs,'question':input
      })
  answer=llm.invoke(formatted)
  return answer

#실행
print('다중 쿼리 검색\n')
result=multi_query_qa.invoke(query)
print(result.content)
# Out:
# 다중 쿼리 검색
#
# query:고대 그리스 철학사의 주요 인물은 누구인가요?
# ...

# %% [markdown]
# RAG 융합

# %%
#query 목록을 생성하는 prompt
from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama import ChatOllama

prompt_rag_fusion=ChatPromptTemplate.from_template(
    '''
    하나의 입력 쿼리를 기반으로 여러 개의 검색 쿼리를 생성하는 유용한 어시스턴트입니다.
    다음과 관련된 여러 검색 쿼리를 영문으로 생성합니다: {question}

    출력(쿼리 4개):
    '''
)

def parse_queries_output(message):
  return message.content.split('\n')

llm=ChatOllama(model="llama3.1",temperature=0)
query_gen=prompt_rag_fusion|llm|parse_queries_output

# %%
query_gen
# Out:
# ChatPromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, template='\n    하나의 입력 쿼리를 기반으로 여러 개의 검색 쿼리를 생성하는 유용한 어시스턴트입니다.\n    다음과 관련된 여러 검색 쿼리를 영문으로 생성합니다: {question}\n\n    출력(쿼리 4개):\n    '), additional_kwargs={})])
# | ChatOllama(model='llama3.1', temperature=0.0)
# | RunnableLambda(parse_queries_output)

# %%
#문서를 재정렬하는 RRF algorithm
def reciprocal_rank_fusion(results: list[list], k=60):
  fused_scores={}
  documents={}
  for docs in results:
    #목록에 있는 각 문서를 순위(목록 내 위치)에 따라 반복
    for rank,doc in enumerate(docs):
      doc_str=doc.page_content
      if doc_str not in fused_scores:
        fused_scores[doc_str]=0
        documents[doc_str]=doc
      fused_scores[doc_str]+=1/(rank+k)

  #융합된 점수를 기준으로 문서를 내림차순으로 정렬하여 최종 재순위 결과를 정리
  reranked_doc_strs=sorted(
      fused_scores,key=lambda d: fused_scores[d],reverse=True
  )
  return [documents[doc_str] for doc_str in reranked_doc_strs]

retrieval_chain=query_gen|retriever.batch|reciprocal_rank_fusion

# %%
retrieval_chain
# Out:
# ChatPromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, template='\n    하나의 입력 쿼리를 기반으로 여러 개의 검색 쿼리를 생성하는 유용한 어시스턴트입니다.\n    다음과 관련된 여러 검색 쿼리를 영문으로 생성합니다: {question}\n\n    출력(쿼리 4개):\n    '), additional_kwargs={})])
# | ChatOllama(model='llama3.1', temperature=0.0)
# | RunnableLambda(parse_queries_output)
# | RunnableLambda(batch)
# | RunnableLambda(lambda d: fused_scores[d])

# %%
#RRF algorithm을 적용한 새로운 검색 체인을 전체 체인에 결합
prompt=ChatPromptTemplate.from_template(
    '''
    다음 컨텍스트만 사용해 질문에 자세히 답하세요.
    컨텍스트:{context}

    질문:{question}
    '''
)

query='고대 그리스 철학사의 주요 인물은 누구인가요?'

@chain
def rag_fusion(input):
  docs=retrieval_chain.invoke(input)
  print(f"query:{input}\ndocs:{docs} ")
  formatted=prompt.invoke(
      {'context':docs,'question':input}
  )
  answer=llm.invoke(formatted)
  return answer

#실행
print('RAG 융합 실행\n')
result=rag_fusion.invoke(query)
print(result.content)
# Out:
# RAG 융합 실행
#
# query:고대 그리스 철학사의 주요 인물은 누구인가요?
# ...

# %% [markdown]
# Hypothetical Document Embeddings(HyDE)

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_ollama import ChatOllama

prompt_hyde=ChatPromptTemplate.from_template(
    '''
    질문에 답할 구절을 작성해 주세요.
    질문: {question}
    구절:
    '''
)

generate_doc=(prompt_hyde|ChatOllama(model="llama3.1",temperature=0)|StrOutputParser())

# %%
generate_doc
# Out:
# ChatPromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, template='\n    질문에 답할 구절을 작성해 주세요.\n    질문: {question}\n    구절:\n    '), additional_kwargs={})])
# | ChatOllama(model='llama3.1', temperature=0.0)
# | StrOutputParser()

# %%
#가상 문서를 retriever의 입력으로 전달해 가상 문서에 대한 embedding 생성
#이 embedding을 기반으로 vector storage에 있는 가장 유사한 문서를 찾는다.
retrieval_chain=generate_doc|retriever
retrieval_chain
# Out:
# ChatPromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, template='\n    질문에 답할 구절을 작성해 주세요.\n    질문: {question}\n    구절:\n    '), additional_kwargs={})])
# | ChatOllama(model='llama3.1', temperature=0.0)
# | StrOutputParser()
# | VectorStoreRetriever(tags=['PGVector', 'OllamaEmbeddings'], vectorstore=<langchain_postgres.vectorstores.PGVector object at 0x7b35ee530c50>, search_kwargs={})

# %%
#검색한 문서를 최종 prompt에 context로 전달해 LLM이 이를 기반으로 출력을 생성하도록 한다.
prompt=ChatPromptTemplate.from_template(
    '''
    다음 컨텍스트만 사용해 질문에 답하세요.
    컨텍스트:{context}

    질문:{question}
    '''
)

llm=ChatOllama(model='llama3.1',temperature=0)

@chain
def qa(input):
  docs=retrieval_chain.invoke(input)
  formatted=prompt.invoke({'context':docs,'question':input})
  answer=llm.invoke(formatted)
  return answer

print('HyDE 실행\n')
result=qa.invoke(query)
# Out:
# HyDE 실행

# %%
result
# Out:
# AIMessage(content='고대 그리스 철학사에서 주요 인물로는 다음과 같은 사람들을 들 수 있습니다.\n\n1. 소크라테스(Socrates): 윤리와 지식에 대한 탐구를 중심으로 한 철학을 발전시켰습니다.\n2. 플라톤(Plato): 소크라테스의 제자로, 아카데미를 설립하고 철학 체계를 개발했습니다.\n3. 아리스토텔레스(Aristotle): 플라톤의 제자로, 다양한 분야에서 중요한 공헌을 했습니다.\n\n이들 외에도 프리소크라테스(Pre-Socratics) 시대에 활동한 인물들이 있습니다. 예를 들어,\n\n1. 테아레트스(Thales of Miletus)\n2. 아낙시만데르(Anaximander)\n3. 헤라클리투스(Heraclitus)\n4. 파르메니데스(Parmenides)\n\n이들은 모두 고대 그리스 철학사에서 중요한 역할을 했습니다.', additional_kwargs={}, response_metadata={'model': 'llama3.1', 'created_at': '2026-04-01T00:35:52.242929582Z', 'done': True, 'done_reason': 'stop', 'total_duration': 10206185204, 'load_duration': 199419431, 'prompt_eval_count': 1021, 'prompt_eval_duration': 1028606083, 'eval_count': 223, 'eval_duration': 8480001124, 'logprobs': None, 'model_name': 'llama3.1', 'model_provider': 'ollama'}, id='lc_run--019d4677-af53-7453-815c-e98c11a1465e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1021, 'output_tokens': 223, 'total_tokens': 1244})

# %% [markdown]
# query routing

# %% [markdown]
# logical routing

# %%
#router schema 정의
from typing import Literal
from langchain_core.prompts import ChatPromptTemplate
from pydantic import BaseModel, Field
from langchain_ollama import ChatOllama
from langchain_core.runnables import RunnableLambda

#데이터 모델 클래스
class RouteQuery(BaseModel):
  #user query을 가장 관련있는 datasource에 라우트한다.
  datasource: Literal['python_docs','js_docs'] = Field(
      ...,
      description='Given a user question, choose which datasource would be most relevant for answering their question'
  )

#prompt template
#함수 호출
llm=ChatOllama(model='llama3.1',temperature=0)

#주어진 schema와 일치하도록 형식화된 출력을 반환하는 모델 래퍼
structured_llm=llm.with_structured_output(RouteQuery)

#prompt
system='''당신은 사용자 질문을 적절한 데이터 소스로 라우팅하는 전문가입니다.
질문이 지목하는 프로그래밍 언어에 따라 해당 데이터 소스로 라우팅하세요.'''
prompt=ChatPromptTemplate(
    [('system',system),('human','{question}')]
)

#라우터 정의
router=prompt |structured_llm

# %%
router
# Out:
# ChatPromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='당신은 사용자 질문을 적절한 데이터 소스로 라우팅하는 전문가입니다.\n질문이 지목하는 프로그래밍 언어에 따라 해당 데이터 소스로 라우팅하세요.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, template='{question}'), additional_kwargs={})])
# ...

# %%
#LLM을 호출해 미리 정의된 schema를 바탕으로 datasource를 추출한다.
#실행
question='''이 코드가 안 돌아가는 이유를 설명해주세요:
from langchain_core.prompts import ChatPromptTemplate
prompt=ChatPromptTemplate.from_messages(['human','speak in {language}'])
prompt.invoke('french')'''
result=router.invoke({'question':question})
print('\nRouting to: ',result)

#결과적으로 LLM이 JSON형식의 출력을 생성했으며, 이 출력은 향후 다양한 작업에서 유용하게 활용될 수 있다.
# Out:
# Routing to:  datasource='python_docs'

# %%
#routing 선택
def choose_route(result):
  if 'python_docs' in result.datasource.lower():
    return 'chain for python_docs'
  else:
    return 'chain for js_docs'

full_chain=router|RunnableLambda(choose_route)

result=full_chain.invoke({'question':question})
print('\nChoose route: ',result)
# Out:
# Choose route:  chain for python_docs

# %% [markdown]
# semantic routing

# %%
from langchain_community.utils.math import cosine_similarity
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_core.runnables import chain
from langchain_ollama import ChatOllama,OllamaEmbeddings

#물리학에 대한 prompt
physics_template='''당신은 매우 똑똑한 물리학 교수입니다.
당신은 물리학에 대한 질문에 간결하고 쉽게 이해할 수 있는 방식으로 대답하는 데 뛰어납니다.
당신이 질문에 대한 답을 모를 때는 모른다고 인정합니다.
다음 질문에 답하세요.: {query}
'''

#수학에 대한 prompt
math_template='''당신은 매우 뛰어난 수학자입니다.
당신은 수학 문제에 답하는 데 뛰어납니다.
당신은 어려운 문제를 구성 요소로 분해하고 구성 요소를 해결한 다음
함께 모아 더 넓은 질문에 대답합니다.
다음 질문에 답하세요.: {query}
'''

#embedding
embeddings=OllamaEmbeddings(model='qwen3-embedding')
prompt_templates=[physics_template,math_template]
prompt_embeddings=embeddings.embed_documents(prompt_templates)

#질문을 prompt에 라우팅
@chain
def prompt_router(query):
  query_embedding=embeddings.embed_query(query)
  similarity=cosine_similarity([query_embedding],prompt_embeddings)[0]
  most_similar=prompt_templates[similarity.argmax()]
  print('수학 프롬프트 사용' if most_similar == math_template else '물리 프롬프트 사용')
  return PromptTemplate.from_template(most_similar)


semantic_router=(prompt_router | ChatOllama(model='llama3.1',temperature=0)|StrOutputParser())

result=semantic_router.invoke('블랙홀이란 무엇인가요?')
print('\n의미론적 라우팅 결과: ',result)
# Out:
# 물리 프롬프트 사용
#
# 의미론적 라우팅 결과:  블랙홀은 우주에서 가장 강력한 물리학적 현상 중 하나입니다. 간단하게 설명하면, 블랙홀은 공간의 일부가 너무密집결하여 그 안으로 들어간 물질이 다시 나오지 못하는 영역을 말합니다.
#
# 예를 들어, 우리가 알고 있는 별들처럼 태양급의 별도 있습니다. 이 별들은 자기 주변에 중력을 가지고 있으며, 자신이 방출하는 빛과 열로 인해 자신의 주위를 돌고 있는 행성을 지배합니다. 하지만 어떤 별은 너무 큰 크기로 자라서, 그중력은 매우 강해지게 됩니다.
#
# 그런데 만약에 이 별의 중력이 너무 강해져서, 자기 주변의 공간이 너무 밀집되면, 그 안으로 들어간 물질은 다시 나오지 못하게 됩니다. 이것을 블랙홀이라고 합니다. 블랙홀은 우주에서 가장 강력한 물리학적 현상 중 하나로, 우리가 아직도 많은 것을 배워야 할 분야입니다.
#
# 블랙홀이란, 공간의 일부가 너무 밀집되어 그 안으로 들어간 물질이 다시 나오지 못하는 영역입니다.

# %%
result=semantic_router.invoke('미분방정식이란 무엇인가요? 간단하게 알려주세요')
print('\n의미론적 라우팅 결과: ',result)
# Out:
# 수학 프롬프트 사용
#
# 의미론적 라우팅 결과:  미분 방정식! 그것은 수학의 꽃 중 하나입니다.
#
# 미분 방정식을 간단히 설명해 드리겠습니다.
#
# **미분**: 미분은 함수의 변화율을 나타내는 것입니다. 예를 들어, x가 1에서 2로 증가할 때 y의 값이 어떻게 변하는지 궁금할 수 있습니다. 미분은 이 변화율을 계산하여 함수의 기울기를 찾습니다.
#
# **방정식**: 방정식은 두 변수 사이의 관계를 나타내는 것입니다. 예를 들어, x와 y가 어떤 규칙에 따라 연결되어 있는지 궁금할 수 있습니다. 방정식은 이러한 규칙을 표현합니다.
#
# **미분 방정식**: 미분 방정식은 미분과 방정식을 결합한 것입니다. 미분 방정식은 함수의 변화율이 특정 규칙에 따라 변하는지를 나타냅니다. 예를 들어, x와 y가 어떤 규칙에 따라 연결되어 있고, 이 규칙이 시간에 따라 변한다면, 미분 방정식은 이러한 변화율을 계산하여 함수의 기울기를 찾습니다.
#
# 미분 방정식을 구성 요소로 분해하면 다음과 같습니다:
#
# 1. **독립 변수** (x): 미분 방정식에서 x는 독립 변수입니다. 예를 들어, 시간이나 위치와 같은 변수가 이에 해당합니다.
# 2. **종속 변수** (y): 미분 방정식에서 y는 종속 변수입니다. 예를 들어, 온도나 속도와 같은 변수가 이에 해당합니다.
# 3. **미분 연산**: 미분 방정식에서는 미분 연산이 사용됩니다. 예를 들어, ∂/∂x (부분 미분) 또는 d/dt (시간 미분)과 같은 연산이 사용됩니다.
# 4. **함수**: 미분 방정식에서 함수는 독립 변수와 종속 변수 사이의 관계를 나타냅니다.
#
# 예를 들어, 다음과 같은 미분 방정식을 생각해 볼 수 있습니다:
#
# ∂u/∂t = c ∂^2u/∂x^2
#
# 이미 분리된 구성 요소는 다음과 같습니다:
#
# * 독립 변수: t (시간)
# * 종속 변수: u (온도)
# * 미분 연산: ∂/∂t (시간 미분) 및 ∂^2/∂x^2 (공간의 두 번째 미분)
# ...

# %% [markdown]
# query 구성

# %%
from langchain_classic.retrievers.self_query.base import SelfQueryRetriever
from langchain_classic.chains.query_constructor.base import AttributeInfo

# %%
#query field 생성
fields=[
    AttributeInfo(
        name='genre',
        description='영화 장르',
        type='string or list[string]',
    ),
    AttributeInfo(
        name='year',
        description='영화 개봉 연도',
        type='integer',
    ),
    AttributeInfo(
        name='director',
        description='영화 감독',
        type='string',
    ),AttributeInfo(
        name='rating',
        description='영화 평점 1-10점',
        type='float',
    ),
]

description='영화에 대한 간략한 정보'
llm=ChatOllama(model='llama3.1',temperature=0)
retriever=SelfQueryRetriever.from_llm(llm,vectorstore,description,fields)

#필터 적용
print(retriever.invoke('평점이 8.5점 이상인 영화가 보고 싶어요.'))

print('\n')

#다양한 필터 적용
print(retriever.invoke(
    '평점이 높은(8.5점 이상) SF영화는 무엇인가요?'
))

# %% [markdown]
# text->SQL문

# %%
# !sudo apt-get update && sudo apt-get instal sqlite3
# !curl -s https://raw.githubusercontent.com/lerocha/chinook-database/master/
# !ChinookDatabase/DataSources/chinook_Sqlite.sql | sqlite3 Chinook.db
# Out:
# Hit:1 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:6 https://cli.github.com/packages stable InRelease
# Hit:7 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:11 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Reading package lists... Done
# ...

# %%
from langchain_community.tools import QuerySQLDatabaseTool
from langchain_community.utilities import SQLDatabase
from langchain_classic.chains import create_sql_query_chain
from langchain_ollama import ChatOllama

#사용할 db 경로로 수정
db=SQLDatabase.from_uri('sqlite:///Chinook.db')
print(db.get_usable_table_names())

llm=ChatOllama(model='llama3.1',temperature=0)

#질문을 SQL query로 변환
write_query=create_sql_query_chain(llm,db)

#SQL query 실행
execute_query=QuerySQLDatabaseTool(db=db)

combined_chain=write_query | execute_query

#체인 실행
result=combined_chain.invoke({'question':'직원(employee)은 모두 몇 명인가요?'})
# Out:
# []
