# %%
# 1. 필수 패키지 및 KoNLPy 설치
# !apt-get update
# !apt-get install g++ openjdk-8-jdk
# !pip install konlpy

# 2. Mecab 엔진 및 형태소 사전(mecab-ko-dic) 설치 스크립트 실행
# !bash <(curl -s https://raw.githubusercontent.com/konlpy/konlpy/master/scripts/mecab.sh)

# 3. Tagger 에러 해결을 위한 최신 파이썬 바인딩 설치
# !pip install mecab-python3

# %%
#은전한닢이라는 형태소 분석 tokenizer
import konlpy
tokenizer=konlpy.tag.Mecab()
tokenizer.morphs("자연어 처리 공부는 재미가 있어요.")
# Out:
# ['자연어', '처리', '공부', '는', '재미', '가', '있', '어요', '.']
